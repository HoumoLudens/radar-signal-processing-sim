# %% [markdown]
# # 04 CFAR Detection
# 1D CA-CFAR 检测示例。

# %%
import os, sys, numpy as np
sys.path.insert(0, os.path.abspath('..'))
from src.processing.cfar import ca_cfar_1d
x = np.random.rand(256) * 0.2
x[120] = 3.0
thr, det = ca_cfar_1d(x)
np.where(det)[0][:10]
