# %% [markdown]
# # 01 FMCW Basics
# 生成 FMCW Chirp 并观察时域信号。

# %%
import os, sys
sys.path.insert(0, os.path.abspath('..'))
from src.core.radar_params import RadarParams
from src.core.signal_generator import generate_tx_chirp
params = RadarParams()
t, tx = generate_tx_chirp(params)
t[:5], tx[:5]
